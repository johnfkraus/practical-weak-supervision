# %%
import pandas as pd
import numpy as np

from snorkel.labeling import labeling_function
from snorkel.labeling import PandasLFApplier

@labeling_function()
def is_big_num(x):
    return 1 if x.num > 52 else 0


dict1 = dict(num=[10, 100], text=["hello", "hi"])
df = pd.DataFrame(dict1)
# df = pd.DataFrame(dict(num=[10, 100], text=["hello", "hi"]))

applier = PandasLFApplier([is_big_num])
"""
PandasLFApplier
    parameter: df
    returns ndarray of labels
"""
# result = applier.apply(pd.DataFrame(dict(num=[10, 100], text=["hello", "hi"])))
result = applier.apply(df)  #  array([[0], [1]])

dict2 = dict(num=[10, 100],num2=[1151, 51], text=["hello", "hi"])
df2 = pd.DataFrame(dict2)
result2 = applier.apply(df2)


dict3 = dict(num2=[1141, 41], num=[10, 100], text=["hello", "hi"])
df3 = pd.DataFrame(dict3)
result3 = applier.apply(df3)

dict4 = dict(num=[1141, 41], num2=[10, 100], text=["hello", "hi"])
df4 = pd.DataFrame(dict4)
result4 = applier.apply(df4)

dict5 = dict(num2=[10, 100], text=["hello", "hi"],num=[1141, 41] )
df5 = pd.DataFrame(dict5)
result5 = applier.apply(df5)  # array([[1], [0]])

# https://www.moonbooks.org/Articles/How-to-store-a-multidimensional-matrix-in-a-dataframe-with-pandas-/Edit/
data = np.random.randint(100,size=(3,3,3))

print(data)
print(data[1,1,0])
# df_new = pd.DataFrame(data)  doesn't work

data = data.reshape(9,3)

print("data = ", data)

iterables = [[0,1,2], [0,1,2]]

index = pd.MultiIndex.from_product(iterables, names=['i', "j"])

df = pd.DataFrame(data=data, index=index, columns = [0,1,2])

df = df.rename_axis("k", axis="columns")

print("df  ", df)
print("df[1] = ", df[1])
# print(df['i'==1]['j'==1]['k'==0])
# df.loc[("bar", "two"), "A"]
df.loc[(0,0)]
print("df.loc[(0,0)] = ", df.loc[(0,0)])
print("df.loc[(0,0), 0] = ", df.loc[(0,0), 0])

print("df.loc[(0,0,0)] = ", df.loc[(0,0,0)])
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 1588.75it/s]
# 100%|██████████| 2/2 [00:00<00:00, 1507.12it/s]
# 100%|██████████| 2/2 [00:00<00:00, 713.01it/s]
# 100%|██████████| 2/2 [00:00<00:00, 1189.03it/s]
# 100%|██████████| 2/2 [00:00<00:00, 1966.85it/s]
# [[[25  1 25]
#   [25 75 62]
#   [74 22 75]]
#
#  [[59  4 91]
#   [91 49 97]
#   [89 96  9]]
#
#  [[63 34 32]
#   [22 74 90]
#   [34 25 99]]]
# 91
# data =  [[25  1 25]
#  [25 75 62]
#  [74 22 75]
#  [59  4 91]
#  [91 49 97]
#  [89 96  9]
#  [63 34 32]
#  [22 74 90]
#  [34 25 99]]
# df   k     0   1   2
# i j
# 0 0  25   1  25
#   1  25  75  62
#   2  74  22  75
# 1 0  59   4  91
#   1  91  49  97
#   2  89  96   9
# 2 0  63  34  32
#   1  22  74  90
#   2  34  25  99
# df[1] =  i  j
# 0  0     1
#    1    75
#    2    22
# 1  0     4
#    1    49
#    2    96
# 2  0    34
#    1    74
#    2    25
# Name: 1, dtype: int64
# df.loc[(0,0)] =  k
# 0    25
# 1     1
# 2    25
# Name: (0, 0), dtype: int64
# df.loc[(0,0), 0] =  25
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# /Users/john.kraus/workspaces/mysnorkel/practical-weak-supervision/snippets/labeling_func.ipynb Cell 1 in <cell line: 69>()
#      <a href='vscode-notebook-cell:/Users/john.kraus/workspaces/mysnorkel/practical-weak-supervision/snippets/labeling_func.ipynb#W0sZmlsZQ%3D%3D?line=65'>66</a> print("df.loc[(0,0)] = ", df.loc[(0,0)])
#      <a href='vscode-notebook-cell:/Users/john.kraus/workspaces/mysnorkel/practical-weak-supervision/snippets/labeling_func.ipynb#W0sZmlsZQ%3D%3D?line=66'>67</a> print("df.loc[(0,0), 0] = ", df.loc[(0,0), 0])
# ---> <a href='vscode-notebook-cell:/Users/john.kraus/workspaces/mysnorkel/practical-weak-supervision/snippets/labeling_func.ipynb#W0sZmlsZQ%3D%3D?line=68'>69</a> print("df.loc[(0,0,0)] = ", df.loc[(0,0,0)])
#
# File ~/opt/anaconda3/envs/prac-weak/lib/python3.10/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/opt/anaconda3/envs/prac-weak/lib/python3.10/site-packages/pandas/core/indexing.py:1143, in _LocIndexer._getitem_tuple(self, tup)
#    1140     return self._getitem_lowerdim(tup)
#    1142 # no multi-index, so validate all of the indexers
# -> 1143 tup = self._validate_tuple_indexer(tup)
#    1145 # ugly hack for GH #836
#    1146 if self._multi_take_opportunity(tup):
#
# File ~/opt/anaconda3/envs/prac-weak/lib/python3.10/site-packages/pandas/core/indexing.py:765, in _LocationIndexer._validate_tuple_indexer(self, key)
#     761 def _validate_tuple_indexer(self, key: tuple) -> tuple:
#     762     """
#     763     Check the key for valid keys across my indexer.
#     764     """
# --> 765     key = self._validate_key_length(key)
#     766     key = self._expand_ellipsis(key)
#     767     for i, k in enumerate(key):
#
# File ~/opt/anaconda3/envs/prac-weak/lib/python3.10/site-packages/pandas/core/indexing.py:812, in _LocationIndexer._validate_key_length(self, key)
#     810             raise IndexingError(_one_ellipsis_message)
#     811         return self._validate_key_length(key)
# --> 812     raise IndexingError("Too many indexers")
#     813 return key
#
# IndexingError: Too many indexers
